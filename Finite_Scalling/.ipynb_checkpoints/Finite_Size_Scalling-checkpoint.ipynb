# %%
import numpy as np
from scipy.special import binom
import matplotlib.pyplot as plt
import os
import errno
import time

# %% [markdown]
# ## Change the directory to where the data is

# %% [markdown]
# ### Check in which directory you are right now

# %%
os.getcwd()
# Out:
# '/home/nahum/Dropbox/CBPF/Python/Codigos/Cluster_Finder/Finite_Scalling'

# %% [markdown]
# ### In my case my data is on .../Python/Cluster_Finder/data

# %%
os.chdir('/home/nahum/Dropbox/CBPF/Python/Codigos/Cluster_Finder/data') 
list_N = os.listdir('.')
N = [int(i) for i in list_N]
N.sort()

# %%
os.chdir(str(N[-1]))

# %%
list_files = os.listdir('.')
list_files.sort()
#list_files

# %%
x2 = list_files[int(len(list_files)/2):]
p_inf = list_files[:int(len(list_files)/2)]
data = zip(p_inf,x2)

# %% [markdown]
# ### Unpacking data

# %%
x2_data = [np.loadtxt(x2[i], unpack=True) for i in range(len(x2))]
p_inf_data = [np.loadtxt(p_inf[i], unpack=True) for i in range(len(p_inf))]

# %% [markdown]
# ### Labeling data axis

# %%
x2_data_x = [x2_data[i][0] for i in range(len(x2_data))]
x2_data_y = [x2_data[i][1] for i in range(len(x2_data))]
p_inf_data_x = [p_inf_data[i][0] for i in range(len(p_inf_data))]
p_inf_data_y = [p_inf_data[i][1] for i in range(len(p_inf_data))]

# %% [markdown]
# ### Taking Mean of the data

# %%
#Probability
p = p_inf_data_x[0]

# %%
x22 = []
x22_r = []
for i in range(len(x2_data_y[0])): #samples
    x22_r = []
    for j in range(len(x2_data_y)): #files
        x22_r.append(x2_data_y[j][i])
    x22.append(np.mean(x22_r))
plt.plot(p, x22, 'o')
plt.show()

# %%
piinf = []
piinf_r = []
for i in range(len(p_inf_data_y[0])): #samples
    piinf_r = []
    for j in range(len(p_inf_data_y)): #files
        piinf_r.append(p_inf_data_y[j][i])
    piinf.append(np.mean(piinf_r))
plt.plot(p, piinf, 'o')
plt.show()

# %%
for i in p_inf_data_y:
    plt.plot(i)
plt.show()

# %%
#Canonical
NN = len(x22)
x2_C = [binom(NN,n)*np.power(p[n],n)*np.power(1-p[n],NN - n) for n in range(NN)]
# Out:
# /home/nahum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot([binom(len(p),n)*np.power(p[0],n)*np.power(1-p[0],len(p) - n) for n in range(len(p))])
plt.show()
# Out:
# /home/nahum/anaconda3/lib/python3.6/site-packages/matplotlib/transforms.py:2902: RuntimeWarning: overflow encountered in double_scalars
#   elif vmax - vmin <= maxabsvalue * tiny:
# /home/nahum/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py:1757: RuntimeWarning: overflow encountered in double_scalars
#   dv = abs(vmax - vmin)  # > 0 as nonsingular is called before.
# /home/nahum/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py:1942: RuntimeWarning: overflow encountered in double_scalars
#   raw_step = (_vmax - _vmin) / nbins
# /home/nahum/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py:1949: RuntimeWarning: invalid value encountered in greater_equal
#   istep = np.nonzero(steps >= raw_step)[0][0]
# --------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# <ipython-input-19-4d49e95c1a12> in <module>
#       1 plt.plot([binom(len(p),n) for n in range(len(p))])
# ----> 2 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1284         if minor:
#    1285             return self.get_minorticklabels()
# -> 1286         return self.get_majorticklabels()
#    1287
#    1288     def get_majorticklines(self):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1389         'get the tick instances; grow as necessary'
#    1390         if numticks is None:
# -> 1391             numticks = len(self.get_major_locator()())
#    1392
#    1393         while len(self.majorTicks) < numticks:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py in __call__(self)
#    1983     def __call__(self):
#    1984         vmin, vmax = self.axis.get_view_interval()
# -> 1985         return self.tick_values(vmin, vmax)
#    1986
#    1987     def tick_values(self, vmin, vmax):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1991         vmin, vmax = mtransforms.nonsingular(
#    1992             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 1993         locs = self._raw_ticks(vmin, vmax)
#    1994
#    1995         prune = self._prune
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    1947             steps = steps[igood]
#    1948
# -> 1949         istep = np.nonzero(steps >= raw_step)[0][0]
#    1950
#    1951         # Classic round_numbers mode may require a larger step.
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ## After the explanation we define a subroutine for unpacking data

# %%
def mea(N):
    """
    Return p, p_inf, x2 and std for a given N.
    """
    os.chdir(str(N)) #Entering the folder
    list_files = os.listdir('.')
    list_files.sort()
    
    x2 = list_files[int(len(list_files)/2):]
    p_inf = list_files[:int(len(list_files)/2)]
    data = zip(p_inf,x2)
    x2_data = [np.loadtxt(x2[i], unpack=True) for i in range(len(x2))]
    p_inf_data = [np.loadtxt(p_inf[i], unpack=True) for i in range(len(p_inf))]
    x2_data_x = [x2_data[i][0] for i in range(len(x2_data))]
    x2_data_y = [x2_data[i][1] for i in range(len(x2_data))]
    p_inf_data_x = [p_inf_data[i][0] for i in range(len(p_inf_data))]
    p_inf_data_y = [p_inf_data[i][1] for i in range(len(p_inf_data))]
    p = p_inf_data_x[0] #Probability
    x22 = []
    x22_r = []
    for i in range(len(x2_data_y[0])): #samples
        x22_r = []
        for j in range(len(x2_data_y)): #files
            x22_r.append(x2_data_y[j][i])
        x22.append(np.mean(x22_r))
    piinf = []
    piinf_r = []
    for i in range(len(p_inf_data_y[0])): #samples
        piinf_r = []
        for j in range(len(p_inf_data_y)): #files
            piinf_r.append(p_inf_data_y[j][i])
        piinf.append(np.mean(piinf_r))
    os.chdir('..') #Leaving the folder
    return p,piinf, x22, np.sqrt(len(x2))

# %% [markdown]
# # Getting data for Finite Size Scalling

# %%
os.chdir('/home/nahum/Dropbox/CBPF/Python/Codigos/Cluster_Finder/data') 
list_N = os.listdir('.')
N = [int(i) for i in list_N]
N.sort()

# %%
prob = []
P_inf_data = []
x2_data = []
o_N = []
for i in N:
    a,b,c,d = mea(i)
    prob.append(a)
    P_inf_data.append(b)
    x2_data.append(c)
    o_N.append(d)

# %% [markdown]
# ## Making a log plot of peaks in order to find the first critical exponent

# %%
peaks_ind = [np.argmax(x2_data[i]) for i in range(len(x2_data))]
peaks_prob = [prob[i][val] for i,val in enumerate(peaks_ind)]
peaks = [x2_data[i][val] for i,val in enumerate(peaks_ind)]
o_peaks = [1./o_N[i] for i in range(len(peaks))]

# %%
plt.errorbar(N,peaks_prob, linestyle= 'None', marker='o')
plt.show()

# %%
plt.errorbar(N,np.log(peaks), linestyle= 'None', marker='o', yerr= o_peaks)
plt.show()

# %% [markdown]
# ## Finding critical probability

# %% [markdown]
# ### Fit a line on N x Log(Peak)

# %%
from scipy.optimize import curve_fit
def f(x,a,b):
    return a*x + b
popt, pcov = curve_fit(f, N, np.log(peaks), sigma=o_peaks)
perr = np.sqrt(np.diag(pcov)) #std of fit

# %% [markdown]
# ### Plot line

# %%
N = np.array(N)
popt_up = popt + 1 * perr
popt_dw = popt - 1 * perr
fit = f(N, *popt)
fit_up = f(N, *popt_up)
fit_dw = f(N, *popt_dw)


plt.errorbar(N,np.log(peaks), linestyle= 'None', marker='o', yerr= o_peaks, label= 'data')
plt.plot(N, f(N,*popt), 'r-', label= 'Curve fit')
plt.fill_between(N, fit_up, fit_dw, alpha=.25, label='1-sigma interval')
plt.legend(loc= 'upper left')
plt.xlabel('N')
plt.ylabel('Peak')
plt.show()

# %%
v = popt[0]
# Out:
# 0.046694068125168589

# %% [markdown]
# ### Critical exponent is  0.047 +/- 0.004

# %% [markdown]
# # Percolating probability

# %%
popt2, pcov2 = curve_fit(f, N, peaks_prob)
perr2 = np.sqrt(np.diag(pcov)) #std of fit

# %%
N = np.array(N)
popt_up2 = popt2 + 1 * perr2
popt_dw2 = popt2 - 1 * perr2
fit2 = f(N, *popt2)
fit_up2 = f(N, *popt_up2)
fit_dw2 = f(N, *popt_dw2)


plt.errorbar(N,peaks_prob, linestyle= 'None', marker='o', label= 'data')
plt.plot(N, f(N,*popt2), 'r-', label= 'Curve fit')
plt.fill_between(N, fit_up2, fit_dw2, alpha=.25, label='1-sigma interval')
plt.legend(loc= 'upper left')
plt.xlabel('N')
plt.ylabel('Peak')
plt.show()

# %%
p_c = popt2[1]

# %% [markdown]
# ### Percolating probability = 0.593 +/- 0.35

# %%
AA = x2_data[0]
AA2 = x2_data[1]
AA3 = x2_data[2]

# %%
N_exp1 = (N[0]**(-popt[0]))
N_exp2 = (N[1]**(-popt[0]))
N_exp3 = (N[2]**(-popt[0]))

# %%
for i,val in enumerate(AA):
    AA[i] = val*N_exp1
for i,val in enumerate(AA2):
    AA2[i] = val*N_exp2
for i,val in enumerate(AA3):
    AA3[i] = val*N_exp3

# %%
plt.plot(prob[0],np.log(AA))
plt.plot(prob[1],np.log(AA2))
plt.plot(prob[2],np.log(AA3))
plt.show()

# %% [markdown]
# ## Rescale with (p-pc)/pc

# %%
N_exp = (N**(-popt[0]))

# %%
p_new = (prob-p_c)/p_c

for i in range(len(x2_data)):
    plt.plot(p_new[i], x2_data[i])
plt.title('Susceptibility')
plt.xlabel(r'$\frac{p - p_c}{p_c}$')
plt.ylabel(r'$\chi$')
plt.show()
for i in range(len(P_inf_data)):
    plt.plot(p_new[i], P_inf_data[i])
plt.title(r'$P_{\inf}$')
plt.xlabel(r'$\frac{p - p_c}{p_c}$')
plt.ylabel(r'$P_{\inf}$')
plt.show()

# %%
x22_N = []
x22_r = []
for j in range(len(x2_data)):
    x22_r = []
    for i in range(len(x2_data[j])): 
        x22_r.append(N_exp[j]*x2_data[j][i])
    x22_N.append(x22_r)

# %%
for i in range(len(x22_N)):
    plt.plot(p_new[i], x22_N[i])
plt.title('Susceptibility')
plt.xlabel(r'$\frac{p - p_c}{p_c}$')
plt.ylabel(r'$\chi$')
plt.show()

# %%
P_inf_N = []
P_inf_r = []
for j in range(len(P_inf_data)):
    P_inf_r = []
    for i in range(len(P_inf_data[j])): 
        P_inf_r.append(N_exp[j]*P_inf_data[j][i])
    P_inf_N.append(P_inf_r)

# %%
for i in range(len(P_inf_data)):
    plt.plot(p_new[i], P_inf_N[i])
plt.title(r'$P_{\inf}$')
plt.xlabel(r'$\frac{p - p_c}{p_c}$')
plt.ylabel(r'$P_{\inf}$')
plt.show()
